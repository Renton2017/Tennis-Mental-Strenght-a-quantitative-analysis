# %% [markdown]
# # DATA IMPORT - PROCESSING -CLEANING -MERGING

# %%
import pandas as pd
import os
import numpy as np
import math
# %matplotlib
import matplotlib as mpl
import dataframe_image as dfi
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)
import gc
import datetime

t_1998 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_1998.csv'
t_1999 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_1999.csv'
t_2000 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2000.csv'
t_2001 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2001.csv'
t_2002 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2002.csv'
t_2003 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2003.csv'
t_2004 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2004.csv'
t_2005 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2005.csv'
t_2006 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2006.csv'
t_2007 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2007.csv'
t_2008 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2008.csv'
t_2009 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2009.csv'
t_2010 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2010.csv'
t_2011 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2011.csv'
t_2012 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2012.csv'
t_2013 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2013.csv'
t_2014 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2014.csv'
t_2015 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2015.csv'
t_2016 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2016.csv'
t_2017 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2017.csv'
t_2018 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2018.csv'
t_2019 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2019.csv'
t_2020 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2020.csv'
#t_2021 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\AUS_OPEN_2021.csv'
t_2021 = r'C:\Users\OLYMPIA\Desktop\T_MENTALSTRENGHT\atp_matches_2021.csv'


t_1998 = pd.read_csv(t_1998, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_1999 = pd.read_csv(t_1999, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2000 = pd.read_csv(t_2000, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2001 = pd.read_csv(t_2001, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2002 = pd.read_csv(t_2002, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2003 = pd.read_csv(t_2003, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2004 = pd.read_csv(t_2004, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2005 = pd.read_csv(t_2005, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2006 = pd.read_csv(t_2006, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2007 = pd.read_csv(t_2007, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2008 = pd.read_csv(t_2008, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2009 = pd.read_csv(t_2009, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2010 = pd.read_csv(t_2010, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2011 = pd.read_csv(t_2011, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2012 = pd.read_csv(t_2012, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2013 = pd.read_csv(t_2013, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2014 = pd.read_csv(t_2014, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2015 = pd.read_csv(t_2015, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2016 = pd.read_csv(t_2016, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2017 = pd.read_csv(t_2017, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2018 = pd.read_csv(t_2018, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2019 = pd.read_csv(t_2019, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2020 = pd.read_csv(t_2020, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
t_2021 = pd.read_csv(t_2021, delimiter=',', encoding='latin_1', usecols =["tourney_id", "tourney_name", "surface", "winner_id", "winner_name", 
                                                                          "winner_hand", "loser_id", "loser_name", "loser_hand", "score", "best_of"])
#t_2021 = pd.read_csv(t_2021, delimiter=';') 
                                                                         

T_total = pd.concat([t_1998, t_1999, t_2000, t_2001, t_2002, t_2003, t_2004, t_2005, t_2006, t_2007, t_2008, t_2009,
                        t_2010, t_2011, t_2012, t_2013, t_2014, t_2015, t_2016, t_2017, t_2018, t_2019, t_2020, t_2021], axis=0)

#####CAREER TOTAL MATCHES
##Nadal
nad_ma = T_total.apply(lambda x : True if (x['winner_id'] == 104745 or x['loser_id'] == 104745) and x['best_of'] == 5
                       else False, axis = 1) 
na_ma_nr = len(nad_ma[nad_ma == True].index) 
###Djokovic
djo_ma = T_total.apply(lambda x : True if (x['winner_id'] == 104925 or x['loser_id'] == 104925) and x['best_of'] == 5
                       else False, axis = 1) 
djo_ma_nr = len(djo_ma[djo_ma == True].index) 
##Federer
fed_ma = T_total.apply(lambda x : True if (x['winner_id'] == 103819 or x['loser_id'] == 103819) and x['best_of'] == 5
                       else False, axis = 1) 
fe_ma_nr = len(fed_ma[fed_ma == True].index) 
##Thiem
thi_ma = T_total.apply(lambda x : True if (x['winner_id'] == 106233 or x['loser_id'] == 106233) and x['best_of'] == 5
                       else False, axis = 1) 
thi_ma_nr = len(thi_ma[thi_ma == True].index) 
##Medvedev
med_ma = T_total.apply(lambda x : True if (x['winner_id'] == 106421 or x['loser_id'] == 106421) and x['best_of'] == 5
                       else False, axis = 1) 
me_ma_nr = len(med_ma[med_ma == True].index) 
#Zverev
zve_ma = T_total.apply(lambda x : True if (x['winner_id'] == 100644 or x['loser_id'] == 100644) and x['best_of'] == 5
                       else False, axis = 1) 
zve_ma_nr = len(zve_ma[zve_ma == True].index) 
#Tsitsipas
tsi_ma = T_total.apply(lambda x : True if (x['winner_id'] == 126774 or x['loser_id'] == 126774) and x['best_of'] == 5
                       else False, axis = 1) 
tsi_ma_nr = len(tsi_ma[tsi_ma == True].index) 
#Schwartzman
sch_ma = T_total.apply(lambda x : True if (x['winner_id'] == 106043 or x['loser_id'] == 106043) and x['best_of'] == 5
                       else False, axis = 1) 
sch_ma_nr = len(sch_ma[sch_ma == True].index) 
#Rublev
rub_ma = T_total.apply(lambda x : True if (x['winner_id'] == 126094 or x['loser_id'] == 126094) and x['best_of'] == 5
                       else False, axis = 1) 
rub_ma_nr = len(rub_ma[rub_ma == True].index) 
#Berettini
ber_ma = T_total.apply(lambda x : True if (x['winner_id'] == 126610 or x['loser_id'] == 126610) and x['best_of'] == 5
                       else False, axis = 1) 
ber_ma_nr = len(ber_ma[ber_ma == True].index) 
#Shapovalov
sha_ma = T_total.apply(lambda x : True if (x['winner_id'] == 133430 or x['loser_id'] == 133430) and x['best_of'] == 5
                       else False, axis = 1) 
sha_ma_nr = len(sha_ma[sha_ma == True].index) 
#Monfils
mon_ma = T_total.apply(lambda x : True if (x['winner_id'] == 104792 or x['loser_id'] == 104792) and x['best_of'] == 5
                       else False, axis = 1) 
mon_ma_nr = len(mon_ma[mon_ma == True].index) 
#Bautista Agut
bau_ma = T_total.apply(lambda x : True if (x['winner_id'] == 105138 or x['loser_id'] == 105138) and x['best_of'] == 5
                       else False, axis = 1) 
bau_ma_nr = len(bau_ma[bau_ma == True].index) 
#Raonic
rao_ma = T_total.apply(lambda x : True if (x['winner_id'] == 105683 or x['loser_id'] == 105683) and x['best_of'] == 5
                       else False, axis = 1) 
rao_ma_nr = len(rao_ma[rao_ma == True].index) 
#Goffin
gof_ma = T_total.apply(lambda x : True if (x['winner_id'] == 105676 or x['loser_id'] == 105676) and x['best_of'] == 5
                       else False, axis = 1) 
gof_ma_nr = len(gof_ma[gof_ma == True].index) 
#Carreno Busta
cab_ma = T_total.apply(lambda x : True if (x['winner_id'] == 105807 or x['loser_id'] == 105807) and x['best_of'] == 5
                       else False, axis = 1) 
cab_ma_nr = len(cab_ma[cab_ma == True].index) 
#Fognini
fog_ma = T_total.apply(lambda x : True if (x['winner_id'] == 104926 or x['loser_id'] == 104926) and x['best_of'] == 5
                       else False, axis = 1) 
fog_ma_nr = len(fog_ma[fog_ma == True].index) 
#Wawrinka
waw_ma = T_total.apply(lambda x : True if (x['winner_id'] == 104527 or x['loser_id'] == 104527) and x['best_of'] == 5
                       else False, axis = 1) 
waw_ma_nr = len(waw_ma[waw_ma == True].index) 
##Auger-Aliassime
faa_ma = T_total.apply(lambda x : True if (x['winner_id'] == 200000 or x['loser_id'] == 200000) and x['best_of'] == 5
                       else False, axis = 1) 
faa_ma_nr = len(faa_ma[faa_ma == True].index) 
##Karen Khachanov
kha_ma = T_total.apply(lambda x : True if (x['winner_id'] == 111575 or x['loser_id'] == 111575) and x['best_of'] == 5
                       else False, axis = 1) 
kha_ma_nr = len(kha_ma[kha_ma == True].index) 
##Dimitrov
dim_ma = T_total.apply(lambda x : True if (x['winner_id'] == 105777 or x['loser_id'] == 105777) and x['best_of'] == 5
                       else False, axis = 1) 
dim_ma_nr = len(dim_ma[dim_ma == True].index) 

T_total[['1set', '2set', '3set', '4set', '5set']] = T_total['score'].str.split(' ', n=4, expand=True)
T_total = T_total.dropna(subset=['4set'])

T_filter =  T_total.query('((winner_id == 104745 or loser_id == 104745) or' #& best_of == 3') #Nadal
                          '(winner_id == 104925 or loser_id == 104925) or'  #Djokovic
                          '(winner_id == 103819 or loser_id == 103819)) & best_of == 5') #Federer
T_filter3 =  T_total.query('((winner_id == 106233 or loser_id == 106233) or' #Thiem
                          '(winner_id == 106421 or loser_id == 106421) or' #Medvedev
                          '(winner_id == 100644 or loser_id == 100644) or' #Zverev
                          '(winner_id == 126774 or loser_id == 126774)) & best_of == 5') #Tsitsipas
T_filter4 =  T_total.query('((winner_id == 106043 or loser_id == 106043) or' #Schwartzman
                          '(winner_id == 126094 or loser_id == 126094) or' #Rublev
                          '(winner_id == 126610 or loser_id == 126610) or' #Berettini
                          '(winner_id == 133430 or loser_id == 133430)) & best_of == 5') #Shapovalov
T_filter5 =  T_total.query('((winner_id == 104792 or loser_id == 104792) or' #Monfils
                          '(winner_id == 105138 or loser_id == 105138) or' #Bautista Agut
                          '(winner_id == 105683 or loser_id == 105683) or' #Raonic                        
                          '(winner_id == 105676 or loser_id == 105676)) & best_of == 5') #Goffin
T_filter2 = T_total.query('((winner_id == 105807 or loser_id == 105807) or' #Carreno Busta
                           '(winner_id == 104926 or loser_id == 104926) or'  #Fognini
                           '(winner_id == 104527 or loser_id == 104527) or' #Wawrinka
                           '(winner_id == 200000 or loser_id == 200000) or' #Auger-Aliassime
                           '(winner_id == 111575 or loser_id == 111575) or' #Karen Khachanov
                          '(winner_id == 105777 or loser_id == 105777)) & best_of == 5') #Grigor Dimitrov

T_new_tot = pd.concat([T_filter, T_filter3, T_filter4, T_filter5, T_filter2], axis=0, ignore_index=True)
T_new_tot.drop(T_new_tot.loc[T_new_tot['4set']=='RET'].index, inplace=True)
T_new_tot.drop(T_new_tot.loc[T_new_tot['4set']=='DEF'].index, inplace=True)
T_new_tot.drop_duplicates(keep='first', inplace=True)
T_new_tot.drop(T_new_tot.loc[T_new_tot['tourney_name']=='ATP Next Gen Finals'].index, inplace=True)

T_new_tot['one_up'] = T_new_tot['1set'].map( lambda x: 1 if x == '6-0' or x == '6-1' 
                                          or x == '6-2'or x == '6-3'or x == '6-4'or x == '7-5'
                                          else 0)
T_new_tot['one_down'] = T_new_tot['1set'].map( lambda x: 1 if x == '0-6' or x == '1-6' 
                                            or x == '2-6'or x == '3-6'or x == '4-6'or x == '5-7'
                                            else 0)
                                         
tiebreak = T_new_tot['1set'].str.startswith('7-6')
tiebk = T_new_tot['1set'].str.startswith('6-7')
T_new_tot.loc[tiebreak, 'one_up'] = 1
T_new_tot.loc[tiebk, 'one_down'] = 1

My_list = T_new_tot['2set'].map( lambda x: 1 if x == '6-0' or x == '6-1' 
                                          or x == '6-2'or x == '6-3'or x == '6-4'or x == '7-5'
                                          else 0)
tiebreak_2up = T_new_tot['2set'].str.startswith('7-6')
My_list.loc[tiebreak_2up] = 1
My_down2_list = T_new_tot['2set'].map( lambda x: 1 if x == '0-6' or x == '1-6' 
                                            or x == '2-6'or x == '3-6'or x == '4-6'or x == '5-7'
                                            else 0)
tiebreak_2down = T_new_tot['2set'].str.startswith('6-7')
My_down2_list.loc[tiebreak_2down] = 1
T_new_tot['two_up'] =  (My_list)* T_new_tot.one_up
T_new_tot['two_down'] =  (My_down2_list)* T_new_tot.one_down

My_third_listup = T_new_tot['3set'].map( lambda x: 1 if x == '6-0' or x == '6-1' 
                                          or x == '6-2'or x == '6-3'or x == '6-4'or x == '7-5'
                                          else 0)

tiebreak_3set = T_new_tot['3set'].str.startswith('7-6')
My_third_listup.loc[tiebreak_3set] = 1

T_new_tot['two-one'] = My_third_listup + T_new_tot['two_up'] + T_new_tot['one_up'] + T_new_tot['one_down'] + T_new_tot['two_down']
T_new_tot['one-two'] = T_new_tot['two-one']

def mycalc(row, col_name):   
    if row[col_name] == 2 :
        val = 1
    elif row[col_name] == 3:
        val = 0
    else:
        val = 0
    return val

def myca(row, col_name):   
    if row[col_name] == 2 :
        val = 0
    elif row[col_name] == 3:
        val = 1
    else:
        val = 1
    return val


T_new_tot['two-one'] = T_new_tot.apply( lambda row : mycalc(row, 'two-one'), axis = 1)
T_new_tot['one-two'] = T_new_tot.apply( lambda row : myca(row, 'one-two'), axis = 1)
del T_total
del T_filter
del T_filter2 

gc.collect()
# Out:
# Using matplotlib backend: Qt5Agg
# 12

# %% [markdown]
# # TESTS

# %%
#T_new_tot.two_up.value_counts().plot(kind='bar')
T_new_tot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1070 entries, 0 to 1186
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   tourney_id    1070 non-null   object
#  1   tourney_name  1070 non-null   object
#  2   surface       1066 non-null   object
#  3   winner_id     1070 non-null   int64
#  4   winner_name   1070 non-null   object
#  5   winner_hand   1070 non-null   object
#  6   loser_id      1070 non-null   int64
#  7   loser_name    1070 non-null   object
#  8   loser_hand    1070 non-null   object
#  9   score         1070 non-null   object
#  10  best_of       1070 non-null   int64
#  11  1set          1070 non-null   object
#  12  2set          1070 non-null   object
#  13  3set          1070 non-null   object
#  14  4set          1070 non-null   object
#  15  5set          399 non-null    object
#  16  one_up        1070 non-null   int64
#  17  one_down      1070 non-null   int64
# ...

# %%
T_new_tot.loc[T_new_tot['winner_id'] == 104925]
# Out:
#     tourney_id     tourney_name surface  winner_id     winner_name  \
# 56    2005-540        Wimbledon   Grass     104925  Novak Djokovic
# 59    2005-560          US Open    Hard     104925  Novak Djokovic
# 60    2005-560          US Open    Hard     104925  Novak Djokovic
# 75    2006-520    Roland Garros    Clay     104925  Novak Djokovic
# 82    2006-540        Wimbledon   Grass     104925  Novak Djokovic
# ..         ...              ...     ...        ...             ...
# 375   2020-520    Roland Garros    Clay     104925  Novak Djokovic
# 376   2021-580  Australian Open    Hard     104925  Novak Djokovic
# 377   2021-580  Australian Open    Hard     104925  Novak Djokovic
# 378   2021-580  Australian Open    Hard     104925  Novak Djokovic
# 379   2021-580  Australian Open    Hard     104925  Novak Djokovic
#
#     winner_hand  loser_id              loser_name loser_hand  \
# 56            R    104198  Guillermo Garcia Lopez          R
# ...

# %% [markdown]
# # BUILDING ONE UP AND ONE DOWN DATAFRAME

# %%
#Big Three Balance one up and one down
###Nadal
ONEUP_W = sum(T_new_tot[T_new_tot['winner_id']==104745]['one_up'])
ONEUP_D = sum(T_new_tot[T_new_tot['loser_id']==104745]['one_down'])
ONEDO_W = sum(T_new_tot[T_new_tot['winner_id']==104745]['one_down'])
ONEDO_D = T_new_tot[T_new_tot['loser_id']==104745]['one_up'].sum()
COU_one_up = ONEUP_W + ONEUP_D
COU_one_do = ONEDO_W + ONEDO_D
wi_na_up = (ONEUP_W/COU_one_up)*100
wi_na_do = (ONEDO_W/COU_one_do)*100
Balance_up = ONEUP_W/COU_one_up - ONEUP_D/COU_one_up
Balance_do = ONEDO_W/COU_one_do - ONEDO_D/COU_one_do
ONEUP_WNo = sum(T_new_tot[T_new_tot['winner_id']==104925]['one_up'])
ONEUP_DNo = sum(T_new_tot[T_new_tot['loser_id']==104925]['one_down'])
ONEDO_WNo = sum(T_new_tot[T_new_tot['winner_id']==104925]['one_down'])
ONEDO_DNo = T_new_tot[T_new_tot['loser_id']==104925]['one_up'].sum()
COU_o_up = ONEUP_WNo + ONEUP_DNo
COU_o_do = ONEDO_WNo + ONEDO_DNo
wi_di_up = (ONEUP_WNo/COU_o_up)*100
wi_di_do = (ONEDO_WNo/COU_o_do)*100
Bal_up = ONEUP_WNo/COU_o_up - ONEUP_DNo/COU_o_up
Bal_do = ONEDO_WNo/COU_o_do - ONEDO_DNo/COU_o_do
Wi_one_up = sum(T_new_tot[T_new_tot['winner_id']==103819]['one_up'])
Lo_one_up = sum(T_new_tot[T_new_tot['loser_id']==103819]['one_down'])
Wi_one_do = sum(T_new_tot[T_new_tot['winner_id']==103819]['one_down'])
Lo_one_do = T_new_tot[T_new_tot['loser_id']==103819]['one_up'].sum()
Cou_one_up = Wi_one_up + Lo_one_up
Cou_one_do = Wi_one_do + Lo_one_do
wi_fe_up = (Wi_one_up/Cou_one_up)*100
wi_fe_do = (Wi_one_do/Cou_one_do)*100
Bala_up = Wi_one_up/Cou_one_up - Lo_one_up/Cou_one_up
Bala_do = Wi_one_do/Cou_one_do - Lo_one_do/Cou_one_do
#Thiem 106233
THUP_W = sum(T_new_tot[T_new_tot['winner_id']==106233]['one_up'])
THEUP_D = sum(T_new_tot[T_new_tot['loser_id']==106233]['one_down'])
THDO_W = sum(T_new_tot[T_new_tot['winner_id']==106233]['one_down'])
THDO_D = T_new_tot[T_new_tot['loser_id']==106233]['one_up'].sum()
THU_one_up = THUP_W + THEUP_D
THU_one_do = THDO_W + THDO_D
wi_th_up = (THUP_W/THU_one_up)*100
wi_th_do = (THDO_W/THU_one_do)*100
thance_up = THUP_W/THU_one_up - THEUP_D/THU_one_up
thance_do = THDO_W/THU_one_do - THDO_D/THU_one_do
#Zverev "100644"
ZWUP_W = sum(T_new_tot[T_new_tot['winner_id']==100644]['one_up'])
ZWEUP_D = sum(T_new_tot[T_new_tot['loser_id']==100644]['one_down'])
ZWDO_W = sum(T_new_tot[T_new_tot['winner_id']==100644]['one_down'])
ZWDO_D = T_new_tot[T_new_tot['loser_id']==100644]['one_up'].sum()
ZWU_one_up = ZWUP_W + ZWEUP_D
ZWU_one_do = ZWDO_W + ZWDO_D
wi_zw_up = (ZWUP_W/ZWU_one_up)*100
wi_zw_do = (ZWDO_W/ZWU_one_do)*100
zwance_up = ZWUP_W/ZWU_one_up - ZWEUP_D/ZWU_one_up
zwance_do = ZWDO_W/ZWU_one_do - ZWDO_D/ZWU_one_do
#Medvedev "106421"
MEUP_W = sum(T_new_tot[T_new_tot['winner_id']==106421]['one_up'])
MEUP_D = sum(T_new_tot[T_new_tot['loser_id']==106421]['one_down'])
MEDO_W = sum(T_new_tot[T_new_tot['winner_id']==106421]['one_down'])
MEDO_D = T_new_tot[T_new_tot['loser_id']==106421]['one_up'].sum()
MEU_one_up = MEUP_W + MEUP_D
MEU_one_do = MEDO_W + MEDO_D
wi_me_up = (MEUP_W/MEU_one_up)*100
wi_me_do = (MEDO_W/MEU_one_do)*100
meance_up = MEUP_W/MEU_one_up - MEUP_D/MEU_one_up
meance_do = MEDO_W/MEU_one_do - MEDO_D/MEU_one_do
#Tsitsipas 126774
TSUP_W = sum(T_new_tot[T_new_tot['winner_id']==126774]['one_up'])
TSUP_D = sum(T_new_tot[T_new_tot['loser_id']==126774]['one_down'])
TSDO_W = sum(T_new_tot[T_new_tot['winner_id']==126774]['one_down'])
TSDO_D = T_new_tot[T_new_tot['loser_id']==126774]['one_up'].sum()
TSU_one_up = TSUP_W + TSUP_D
TSU_one_do = TSDO_W + TSDO_D
wi_ts_up = (TSUP_W/TSU_one_up)*100
wi_ts_do = (TSDO_W/TSU_one_do)*100
tsance_up = TSUP_W/TSU_one_up - TSUP_D/TSU_one_up
tsance_do = TSDO_W/TSU_one_do - TSDO_D/TSU_one_do
#Rublev 126094
RUUP_W = sum(T_new_tot[T_new_tot['winner_id']==126094]['one_up'])
RUUP_D = sum(T_new_tot[T_new_tot['loser_id']==126094]['one_down'])
RUDO_W = sum(T_new_tot[T_new_tot['winner_id']==126094]['one_down'])
RUDO_D = T_new_tot[T_new_tot['loser_id']==126094]['one_up'].sum()
RUU_one_up = RUUP_W + RUUP_D
RUU_one_do = RUDO_W + RUDO_D
wi_ru_up = (RUUP_W/RUU_one_up)*100
wi_ru_do = (RUDO_W/RUU_one_do)*100
ruance_up = RUUP_W/RUU_one_up - RUUP_D/RUU_one_up
ruance_do = RUDO_W/RUU_one_do - RUDO_D/RUU_one_do
#Schwartzman 106043
SCUP_W = sum(T_new_tot[T_new_tot['winner_id']==106043]['one_up'])
SCUP_D = sum(T_new_tot[T_new_tot['loser_id']==106043]['one_down'])
SCDO_W = sum(T_new_tot[T_new_tot['winner_id']==106043]['one_down'])
SCDO_D = T_new_tot[T_new_tot['loser_id']==106043]['one_up'].sum()
SCU_one_up = SCUP_W + SCUP_D
SCU_one_do = SCDO_W + SCDO_D
wi_sc_up = (SCUP_W/SCU_one_up)*100
wi_sc_do = (SCDO_W/SCU_one_do)*100
scance_up = SCUP_W/SCU_one_up - SCUP_D/SCU_one_up
scance_do = SCDO_W/SCU_one_do - SCDO_D/SCU_one_do
##Berettini 126610
BEUP_W = sum(T_new_tot[T_new_tot['winner_id']==126610]['one_up'])
BEUP_D = sum(T_new_tot[T_new_tot['loser_id']==126610]['one_down'])
BEDO_W = sum(T_new_tot[T_new_tot['winner_id']==126610]['one_down'])
BEDO_D = T_new_tot[T_new_tot['loser_id']==126610]['one_up'].sum()
BEU_one_up = BEUP_W + BEUP_D
BEU_one_do = BEDO_W + BEDO_D
wi_be_up = (BEUP_W/BEU_one_up)*100
wi_be_do = (BEDO_W/BEU_one_do)*100
beance_up = BEUP_W/BEU_one_up - BEUP_D/BEU_one_up
beance_do = BEDO_W/BEU_one_do - BEDO_D/BEU_one_do
#Shapovalov 133430
SHUP_W = sum(T_new_tot[T_new_tot['winner_id']==133430]['one_up'])
SHUP_D = sum(T_new_tot[T_new_tot['loser_id']==133430]['one_down'])
SHDO_W = sum(T_new_tot[T_new_tot['winner_id']==133430]['one_down'])
SHDO_D = T_new_tot[T_new_tot['loser_id']==133430]['one_up'].sum()
SHU_one_up = SHUP_W + SHUP_D
SHU_one_do = SHDO_W + SHDO_D
wi_sh_up = (SHUP_W/SHU_one_up)*100
wi_sh_do = (SHDO_W/SHU_one_do)*100
shance_up = SHUP_W/SHU_one_up - SHUP_D/SHU_one_up
shance_do = SHDO_W/SHU_one_do - SHDO_D/SHU_one_do
#Monfils 104792
MOUP_W = sum(T_new_tot[T_new_tot['winner_id']==104792]['one_up'])
MOUP_D = sum(T_new_tot[T_new_tot['loser_id']==104792]['one_down'])
MODO_W = sum(T_new_tot[T_new_tot['winner_id']==104792]['one_down'])
MODO_D = T_new_tot[T_new_tot['loser_id']==104792]['one_up'].sum()
MOU_one_up = MOUP_W + MOUP_D
MOU_one_do = MODO_W + MODO_D
wi_mo_up = (MOUP_W/MOU_one_up)*100
wi_mo_do = (MODO_W/MOU_one_do)*100
moance_up = MOUP_W/MOU_one_up - MOUP_D/MOU_one_up
moance_do = MODO_W/MOU_one_do - MODO_D/MOU_one_do
###Bautista Agut 105138
BAUP_W = sum(T_new_tot[T_new_tot['winner_id']==105138]['one_up'])
BAUP_D = sum(T_new_tot[T_new_tot['loser_id']==105138]['one_down'])
BADO_W = sum(T_new_tot[T_new_tot['winner_id']==105138]['one_down'])
BADO_D = T_new_tot[T_new_tot['loser_id']==105138]['one_up'].sum()
BAU_one_up = BAUP_W + BAUP_D
BAU_one_do = BADO_W + BADO_D
wi_ba_up = (BAUP_W/BAU_one_up)*100
wi_ba_do = (BADO_W/BAU_one_do)*100
baance_up = BAUP_W/BAU_one_up - BAUP_D/BAU_one_up
baance_do = BADO_W/BAU_one_do - BADO_D/BAU_one_do
#Raonic  "105683"
RAUP_W = sum(T_new_tot[T_new_tot['winner_id']==105683]['one_up'])
RAUP_D = sum(T_new_tot[T_new_tot['loser_id']==105683]['one_down'])
RADO_W = sum(T_new_tot[T_new_tot['winner_id']==105683]['one_down'])
RADO_D = T_new_tot[T_new_tot['loser_id']==105683]['one_up'].sum()
RAU_one_up = RAUP_W + RAUP_D
RAU_one_do = RADO_W + RADO_D
wi_ra_up = (RAUP_W/RAU_one_up)*100
wi_ra_do = (RADO_W/RAU_one_do)*100
raance_up = RAUP_W/RAU_one_up - RAUP_D/RAU_one_up
raance_do = RADO_W/RAU_one_do - RADO_D/RAU_one_do
#Goffin "105676"
GOUP_W = sum(T_new_tot[T_new_tot['winner_id']==105676]['one_up'])
GOUP_D = sum(T_new_tot[T_new_tot['loser_id']==105676]['one_down'])
GODO_W = sum(T_new_tot[T_new_tot['winner_id']==105676]['one_down'])
GODO_D = T_new_tot[T_new_tot['loser_id']==105676]['one_up'].sum()
GOU_one_up = GOUP_W + GOUP_D
GOU_one_do = GODO_W + GODO_D
wi_go_up = (GOUP_W/GOU_one_up)*100
wi_go_do = (GODO_W/GOU_one_do)*100
goance_up = GOUP_W/GOU_one_up - GOUP_D/GOU_one_up
goance_do = GODO_W/GOU_one_do - GODO_D/GOU_one_do
#Carreno Busta 105807
CAUP_W = sum(T_new_tot[T_new_tot['winner_id']==105807]['one_up'])
CAUP_D = sum(T_new_tot[T_new_tot['loser_id']==105807]['one_down'])
CADO_W = sum(T_new_tot[T_new_tot['winner_id']==105807]['one_down'])
CADO_D = T_new_tot[T_new_tot['loser_id']==105807]['one_up'].sum()
CAU_one_up = CAUP_W + CAUP_D
CAU_one_do = CADO_W + CADO_D
wi_ca_up = (CAUP_W/CAU_one_up)*100
wi_ca_do = (CADO_W/CAU_one_do)*100
caance_up = CAUP_W/CAU_one_up - CAUP_D/CAU_one_up
caance_do = CADO_W/CAU_one_do - CADO_D/CAU_one_do
# "104527" #Wawrinka
WAUP_W = sum(T_new_tot[T_new_tot['winner_id']==104527]['one_up'])
WAUP_D = sum(T_new_tot[T_new_tot['loser_id']==104527]['one_down'])
WADO_W = sum(T_new_tot[T_new_tot['winner_id']==104527]['one_down'])
WADO_D = T_new_tot[T_new_tot['loser_id']==104527]['one_up'].sum()
WAU_one_up = WAUP_W + WAUP_D
WAU_one_do = WADO_W + WADO_D
wi_wa_up = (WAUP_W/WAU_one_up)*100
wi_wa_do = (WADO_W/WAU_one_do)*100
waance_up = WAUP_W/WAU_one_up - WAUP_D/WAU_one_up
waance_do = WADO_W/WAU_one_do - WADO_D/WAU_one_do
#Fognini 104926
FOUP_W = sum(T_new_tot[T_new_tot['winner_id']==104926]['one_up'])
FOUP_D = sum(T_new_tot[T_new_tot['loser_id']==104926]['one_down'])
FODO_W = sum(T_new_tot[T_new_tot['winner_id']==104926]['one_down'])
FODO_D = T_new_tot[T_new_tot['loser_id']==104926]['one_up'].sum()
FOU_one_up = FOUP_W + FOUP_D
FOU_one_do = FODO_W + FODO_D
wi_fo_up = (FOUP_W/FOU_one_up)*100
wi_fo_do = (FODO_W/FOU_one_do)*100
foance_up = FOUP_W/FOU_one_up - FOUP_D/FOU_one_up
foance_do = FODO_W/FOU_one_do - FODO_D/FOU_one_do
#Auger-Aliassime "200000"
FAUP_W = sum(T_new_tot[T_new_tot['winner_id']==200000]['one_up'])
FAUP_D = sum(T_new_tot[T_new_tot['loser_id']==200000]['one_down'])
FADO_W = sum(T_new_tot[T_new_tot['winner_id']==200000]['one_down'])
FADO_D = T_new_tot[T_new_tot['loser_id']==200000]['one_up'].sum()
FAU_one_up = FAUP_W + FAUP_D
FAU_one_do = FADO_W + FADO_D
wi_faa_up = (FAUP_W/FAU_one_up)*100
wi_faa_do = (FADO_W/FAU_one_do)*100
faance_up = FAUP_W/FAU_one_up - FAUP_D/FAU_one_up
faance_do = FADO_W/FAU_one_do - FADO_D/FAU_one_do
#Karen Khachanov "111575"
KKUP_W = sum(T_new_tot[T_new_tot['winner_id']==111575]['one_up'])
KKUP_D = sum(T_new_tot[T_new_tot['loser_id']==111575]['one_down'])
KKDO_W = sum(T_new_tot[T_new_tot['winner_id']==111575]['one_down'])
KKDO_D = T_new_tot[T_new_tot['loser_id']==111575]['one_up'].sum()
KKU_one_up = KKUP_W + KKUP_D
KKU_one_do = KKDO_W + KKDO_D
wi_kk_up = (KKUP_W/KKU_one_up)*100
wi_kk_do = (KKDO_W/KKU_one_do)*100
kkance_up = KKUP_W/KKU_one_up - KKUP_D/KKU_one_up
kkance_do = KKDO_W/KKU_one_do - KKDO_D/KKU_one_do
#Grigor Dimitrov "105777"
GDUP_W = sum(T_new_tot[T_new_tot['winner_id']==105777]['one_up'])
GDUP_D = sum(T_new_tot[T_new_tot['loser_id']==105777]['one_down'])
GDDO_W = sum(T_new_tot[T_new_tot['winner_id']==105777]['one_down'])
GDDO_D = T_new_tot[T_new_tot['loser_id']==105777]['one_up'].sum()
GDU_one_up = GDUP_W + GDUP_D
GDU_one_do = GDDO_W + GDDO_D
wi_gd_up = (GDUP_W/GDU_one_up)*100
wi_gd_do = (GDDO_W/GDU_one_do)*100
gdance_up = GDUP_W/GDU_one_up - GDUP_D/GDU_one_up
gdance_do = GDDO_W/GDU_one_do - GDDO_D/GDU_one_do


data = [['Federer', fe_ma_nr, Wi_one_up , Lo_one_up, Wi_one_do, Lo_one_do, wi_fe_up, wi_fe_do, Bala_up, Bala_do], 
        ['Nadal', na_ma_nr, ONEUP_W, ONEUP_D, ONEDO_W, ONEDO_D, wi_na_up, wi_na_do, Balance_up, Balance_do], 
        ['Djokovic', djo_ma_nr, ONEUP_WNo, ONEUP_DNo, ONEDO_WNo, ONEDO_DNo, wi_di_up, wi_di_do,  Bal_up, Bal_do],
        ['Thiem', thi_ma_nr, THUP_W, THEUP_D, THDO_W, THDO_D, wi_th_up, wi_th_do, thance_up, thance_do],
        ['Zverev', zve_ma_nr, ZWUP_W, ZWEUP_D, ZWDO_W, ZWDO_D, wi_zw_up, wi_zw_do, zwance_up, zwance_do],
        ['Medvedev', me_ma_nr, MEUP_W, MEUP_D, MEDO_W, MEDO_D, wi_me_up, wi_me_do, meance_up, meance_do],
        ['Rublev', rub_ma_nr, RUUP_W, RUUP_D, RUDO_W, RUDO_D, wi_ru_up, wi_ru_do, ruance_up, ruance_do],
        ['Tsitsipas', tsi_ma_nr, TSUP_W, TSUP_D, TSDO_W, TSDO_D, wi_ts_up, wi_ts_do, tsance_up, tsance_do],
        ['Schwartzman', sch_ma_nr, SCUP_W, SCUP_D, SCDO_W, SCDO_D, wi_sc_up, wi_sc_do, scance_up, scance_do],
        ['Berrettini', ber_ma_nr, BEUP_W, BEUP_D, BEDO_W, BEDO_D, wi_be_up, wi_be_do, beance_up, beance_do],
        ['Shapovalov', sha_ma_nr, SHUP_W, SHUP_D, SHDO_W, SHDO_D, wi_sh_up, wi_sh_do, shance_up, shance_do],
        ['Monfils', mon_ma_nr, MOUP_W, MOUP_D, MODO_W, MODO_D, wi_mo_up, wi_mo_do, moance_up, moance_do],
        ['Bautista-Agut', bau_ma_nr, BAUP_W, BAUP_D, BADO_W, BADO_D, wi_ba_up, wi_ba_do, baance_up, baance_do],
        ['Raonic', rao_ma_nr, RAUP_W, RAUP_D, RADO_W, RADO_D, wi_ra_up, wi_ra_do, raance_up, raance_do],
        ['Goffin', gof_ma_nr, GOUP_W, GOUP_D, GODO_W, GODO_D, wi_go_up, wi_go_do, goance_up, goance_do],
        ['Carreno Busta', cab_ma_nr, CAUP_W, CAUP_D, CADO_W, CADO_D, wi_ca_up, wi_ca_do, caance_up, caance_do],
        ['Wawrinka', waw_ma_nr, WAUP_W, WAUP_D, WADO_W, WADO_D, wi_wa_up, wi_wa_do, waance_up, waance_do],
        ['Fognini', fog_ma_nr, FOUP_W, FOUP_D, FODO_W, FODO_D, wi_fo_up, wi_fo_do, foance_up, foance_do],
        ['Auger-Aliassime', faa_ma_nr, FAUP_W, FAUP_D, FADO_W, FADO_D, wi_faa_up, wi_faa_do, faance_up, faance_do],
        ['Khachanov', kha_ma_nr, KKUP_W, KKUP_D, KKDO_W, KKDO_D, wi_kk_up, wi_kk_do, kkance_up, kkance_do],
        ['Dimitrov', dim_ma_nr, GDUP_W, GDUP_D, GDDO_W, GDDO_D, wi_gd_up, wi_gd_do, gdance_up, gdance_do]] 


df_1 =pd.DataFrame(data, columns = ['Name', 'overall_ma','Nr_Win_Up', 'Nr_Def_Up', 'Nr_Win_Do', 'Nr_Def_Do', 
                                    'Per_Win_up', 'Per_Win_down', 'Balance_up', 'Balance_down']) 


df_1['Bal_matches'] = df_1['Nr_Win_Up']+ df_1['Nr_Def_Up']+ df_1['Nr_Win_Do']+ df_1['Nr_Def_Do']

df_1['weight_fights'] = df_1['Bal_matches']/df_1['overall_ma']

df_1 = df_1[['Name', 'overall_ma', 'Bal_matches', 'weight_fights', 'Per_Win_up', 
         'Per_Win_down', 'Balance_up', 'Balance_down']].sort_values(by='Bal_matches', ascending=False).round(3)

df1_styled = df_1.style.background_gradient()
df1_styled.to_excel("df1_styled.xlsx")
#df_1.dfi.export('df_1.png')

# %% [markdown]
# # DATA VISUALIZATION FIRST DATAFRAME

# %%
# Declaring the figure or the plot (y, x) or (width, height)
plt.figure(figsize=[15, 10])
# Data to be plotted
# Using numpy to group 3 different data with bars
X = np.arange(len(df_1))
# Passing the parameters to the bar function, this is the main function which creates the bar plot
# Using X now to align the bars side by side
plt.bar(X, df_1.Balance_up, color = 'g', width = 0.25)
plt.bar(X + 0.25, df_1.Balance_down, color = 'b', width = 0.25)
# Creating the legend of the bars in the plot
plt.legend(['Saldo_1_su', 'Saldo_1_giù'], loc='lower right', fontsize=15)
# Overiding the x axis with the tennis players names
plt.xticks([i + 0.25 for i in range(21)], ['Fed', 'Djo', 'Waw', 'Nad', 'Mon', 'Fog', 'Rao', 'Thi', 'Gof', 'Bau', 
                                          'Dim', 'Zwe', 'CaB', 'Kha', 'Sch', 'Med', 'Sha', 'Tsi', 'Rub', 'Ber',
                                          'Faa'], fontsize=13)
#plt.xticks([i + 0.25 for i in range(df_2.Name)])
#plt.xticks(df_2.Name)
# Giving the tilte for the plot
plt.title("Saldi 1 Set avanti e indietro TOP 21", fontsize=25, fontweight="bold")
# Namimg the x and y axis
plt.xlabel('Tennisti', fontsize=15, fontweight="bold")
plt.ylabel('Valori', fontsize=15, fontweight="bold")
# Saving the plot as a 'png'
plt.savefig('Three_out_five_Balances_ups_downs.png')
# Displaying the bar plot
plt.show()

# %% [markdown]
# # BUILDING TWO UP AND TWO DOWN DATAFRAME

# %%
#Big Three Balance two up and two down
TWOUP_W = sum(T_new_tot[T_new_tot['winner_id']==104745]['two_up'])
TWOUP_D = sum(T_new_tot[T_new_tot['loser_id']==104745]['two_down'])
TWODO_W = sum(T_new_tot[T_new_tot['winner_id']==104745]['two_down'])
TWODO_D = T_new_tot[T_new_tot['loser_id']==104745]['two_up'].sum()
COU_two_up = TWOUP_W + TWOUP_D
COU_two_do = TWODO_W + TWODO_D
wi_na_up = (TWOUP_W/COU_two_up)*100
wi_na_do = (TWODO_W/COU_two_do)*100
Balance_two_up = TWOUP_W/COU_two_up - TWOUP_D/COU_two_up
Balance_two_do = TWODO_W/COU_two_do - TWODO_D/COU_two_do
TWOUP_WNo = sum(T_new_tot[T_new_tot['winner_id']==104925]['two_up'])
TWOUP_DNo = sum(T_new_tot[T_new_tot['loser_id']==104925]['two_down'])
TWODO_WNo = sum(T_new_tot[T_new_tot['winner_id']==104925]['two_down'])
TWODO_DNo = T_new_tot[T_new_tot['loser_id']==104925]['two_up'].sum()
COU_to_up = TWOUP_WNo + TWOUP_DNo
COU_to_do = TWODO_WNo + TWODO_DNo
wi_di_up = (TWOUP_WNo/COU_to_up)*100
wi_di_do = (TWODO_WNo/COU_to_do)*100
Bal_two_up = TWOUP_WNo/COU_to_up - TWOUP_DNo/COU_to_up
Bal_two_do = TWODO_WNo/COU_to_do - TWODO_DNo/COU_to_do
Wi_two_up = sum(T_new_tot[T_new_tot['winner_id']==103819]['two_up'])
Lo_two_up = sum(T_new_tot[T_new_tot['loser_id']==103819]['two_down'])
Wi_two_do = sum(T_new_tot[T_new_tot['winner_id']==103819]['two_down'])
Lo_two_do = T_new_tot[T_new_tot['loser_id']==103819]['two_up'].sum()
Cou_two_up = Wi_two_up + Lo_two_up
Cou_two_do = Wi_two_do + Lo_two_do
wi_fe_up = (Wi_two_up/Cou_two_up)*100
wi_fe_do = (Wi_two_do/Cou_two_do)*100
Bala_to_up = Wi_two_up/Cou_two_up - Lo_two_up/Cou_two_up
Bala_to_do = Wi_two_do/Cou_two_do - Lo_two_do/Cou_two_do
#Thiem 106233
THtwo_W = sum(T_new_tot[T_new_tot['winner_id']==106233]['two_up'])
THtwo_D = sum(T_new_tot[T_new_tot['loser_id']==106233]['two_down'])
THtwoDO_W = sum(T_new_tot[T_new_tot['winner_id']==106233]['two_down'])
THtwoDO_D = T_new_tot[T_new_tot['loser_id']==106233]['two_up'].sum()
THU_two_up = THtwo_W + THtwo_D
THD_two_do = THtwoDO_W + THtwoDO_D
wi_th_up = (THtwo_W/THU_two_up)*100
wi_th_do = (THtwoDO_W/THD_two_do)*100
twoth_up = THtwo_W/THU_two_up - THtwo_D/THU_two_up
twoth_do = THtwoDO_W/THD_two_do - THtwoDO_D/THD_two_do
#Zverev "100644"
ZWUP_W = sum(T_new_tot[T_new_tot['winner_id']==100644]['two_up'])
ZWEUP_D = sum(T_new_tot[T_new_tot['loser_id']==100644]['two_down'])
ZWDO_W = sum(T_new_tot[T_new_tot['winner_id']==100644]['two_down'])
ZWDO_D = T_new_tot[T_new_tot['loser_id']==100644]['two_up'].sum()
ZWU_one_up = ZWUP_W + ZWEUP_D
ZWU_one_do = ZWDO_W + ZWDO_D
wi_zw_up = (ZWUP_W/ZWU_one_up)*100
wi_zw_do = (ZWDO_W/ZWU_one_do)*100
zwance_up = ZWUP_W/ZWU_one_up - ZWEUP_D/ZWU_one_up
zwance_do = ZWDO_W/ZWU_one_do - ZWDO_D/ZWU_one_do
#Medvedev "106421"
MEUP_W = sum(T_new_tot[T_new_tot['winner_id']==106421]['two_up'])
MEUP_D = sum(T_new_tot[T_new_tot['loser_id']==106421]['two_down'])
MEDO_W = sum(T_new_tot[T_new_tot['winner_id']==106421]['two_down'])
MEDO_D = T_new_tot[T_new_tot['loser_id']==106421]['two_up'].sum()
MEU_one_up = MEUP_W + MEUP_D
MEU_one_do = MEDO_W + MEDO_D
wi_me_up = (MEUP_W/MEU_one_up)*100
wi_me_do = (MEDO_W/MEU_one_do)*100
meance_up = MEUP_W/MEU_one_up - MEUP_D/MEU_one_up
meance_do = MEDO_W/MEU_one_do - MEDO_D/MEU_one_do
#Tsitsipas 126774
TSUP_W = sum(T_new_tot[T_new_tot['winner_id']==126774]['two_up'])
TSUP_D = sum(T_new_tot[T_new_tot['loser_id']==126774]['two_down'])
TSDO_W = sum(T_new_tot[T_new_tot['winner_id']==126774]['two_down'])
TSDO_D = T_new_tot[T_new_tot['loser_id']==126774]['two_up'].sum()
TSU_one_up = TSUP_W + TSUP_D
TSU_one_do = TSDO_W + TSDO_D
wi_ts_up = (TSUP_W/TSU_one_up)*100
wi_ts_do = (TSDO_W/TSU_one_do)*100
tsance_up = TSUP_W/TSU_one_up - TSUP_D/TSU_one_up
tsance_do = TSDO_W/TSU_one_do - TSDO_D/TSU_one_do
#Rublev 126094
RUUP_W = sum(T_new_tot[T_new_tot['winner_id']==126094]['two_up'])
RUUP_D = sum(T_new_tot[T_new_tot['loser_id']==126094]['two_down'])
RUDO_W = sum(T_new_tot[T_new_tot['winner_id']==126094]['two_down'])
RUDO_D = T_new_tot[T_new_tot['loser_id']==126094]['two_up'].sum()
RUU_one_up = RUUP_W + RUUP_D
RUU_one_do = RUDO_W + RUDO_D
wi_ru_up = (RUUP_W/RUU_one_up)*100
wi_ru_do = (RUDO_W/RUU_one_do)*100
ruance_up = RUUP_W/RUU_one_up - RUUP_D/RUU_one_up
ruance_do = RUDO_W/RUU_one_do - RUDO_D/RUU_one_do
#Schwartzman 106043
SCUP_W = sum(T_new_tot[T_new_tot['winner_id']==106043]['two_up'])
SCUP_D = sum(T_new_tot[T_new_tot['loser_id']==106043]['two_down'])
SCDO_W = sum(T_new_tot[T_new_tot['winner_id']==106043]['two_down'])
SCDO_D = T_new_tot[T_new_tot['loser_id']==106043]['two_up'].sum()
SCU_one_up = SCUP_W + SCUP_D
SCU_one_do = SCDO_W + SCDO_D
wi_sc_up = (SCUP_W/SCU_one_up)*100
wi_sc_do = (SCDO_W/SCU_one_do)*100
scance_up = SCUP_W/SCU_one_up - SCUP_D/SCU_one_up
scance_do = SCDO_W/SCU_one_do - SCDO_D/SCU_one_do
##Berettini 126610
BEUP_W = sum(T_new_tot[T_new_tot['winner_id']==126610]['two_up'])
BEUP_D = sum(T_new_tot[T_new_tot['loser_id']==126610]['two_down'])
BEDO_W = sum(T_new_tot[T_new_tot['winner_id']==126610]['two_down'])
BEDO_D = T_new_tot[T_new_tot['loser_id']==126610]['two_up'].sum()
BEU_one_up = BEUP_W + BEUP_D
BEU_one_do = BEDO_W + BEDO_D
wi_be_up = (BEUP_W/BEU_one_up)*100
wi_be_do = (BEDO_W/BEU_one_do)*100
beance_up = BEUP_W/BEU_one_up - BEUP_D/BEU_one_up
beance_do = BEDO_W/BEU_one_do - BEDO_D/BEU_one_do
#Shapovalov 133430
SHUP_W = sum(T_new_tot[T_new_tot['winner_id']==133430]['two_up'])
SHUP_D = sum(T_new_tot[T_new_tot['loser_id']==133430]['two_down'])
SHDO_W = sum(T_new_tot[T_new_tot['winner_id']==133430]['two_down'])
SHDO_D = T_new_tot[T_new_tot['loser_id']==133430]['two_up'].sum()
SHU_one_up = SHUP_W + SHUP_D
SHU_one_do = SHDO_W + SHDO_D
wi_sh_up = (SHUP_W/SHU_one_up)*100
wi_sh_do = (SHDO_W/SHU_one_do)*100
shance_up = SHUP_W/SHU_one_up - SHUP_D/SHU_one_up
shance_do = SHDO_W/SHU_one_do - SHDO_D/SHU_one_do
#Monfils 104792
MOUP_W = sum(T_new_tot[T_new_tot['winner_id']==104792]['two_up'])
MOUP_D = sum(T_new_tot[T_new_tot['loser_id']==104792]['two_down'])
MODO_W = sum(T_new_tot[T_new_tot['winner_id']==104792]['two_down'])
MODO_D = T_new_tot[T_new_tot['loser_id']==104792]['two_up'].sum()
MOU_one_up = MOUP_W + MOUP_D
MOU_one_do = MODO_W + MODO_D
wi_mo_up = (MOUP_W/MOU_one_up)*100
wi_mo_do = (MODO_W/MOU_one_do)*100
moance_up = MOUP_W/MOU_one_up - MOUP_D/MOU_one_up
moance_do = MODO_W/MOU_one_do - MODO_D/MOU_one_do
###Bautista Agut 105138
BAUP_W = sum(T_new_tot[T_new_tot['winner_id']==105138]['two_up'])
BAUP_D = sum(T_new_tot[T_new_tot['loser_id']==105138]['two_down'])
BADO_W = sum(T_new_tot[T_new_tot['winner_id']==105138]['two_down'])
BADO_D = T_new_tot[T_new_tot['loser_id']==105138]['two_up'].sum()
BAU_one_up = BAUP_W + BAUP_D
BAU_one_do = BADO_W + BADO_D
wi_ba_up = (BAUP_W/BAU_one_up)*100
wi_ba_do = (BADO_W/BAU_one_do)*100
baance_up = BAUP_W/BAU_one_up - BAUP_D/BAU_one_up
baance_do = BADO_W/BAU_one_do - BADO_D/BAU_one_do
#Raonic  "105683"
RAUP_W = sum(T_new_tot[T_new_tot['winner_id']==105683]['two_up'])
RAUP_D = sum(T_new_tot[T_new_tot['loser_id']==105683]['two_down'])
RADO_W = sum(T_new_tot[T_new_tot['winner_id']==105683]['two_down'])
RADO_D = T_new_tot[T_new_tot['loser_id']==105683]['two_up'].sum()
RAU_one_up = RAUP_W + RAUP_D
RAU_one_do = RADO_W + RADO_D
wi_ra_up = (RAUP_W/RAU_one_up)*100
wi_ra_do = (RADO_W/RAU_one_do)*100
raance_up = RAUP_W/RAU_one_up - RAUP_D/RAU_one_up
raance_do = RADO_W/RAU_one_do - RADO_D/RAU_one_do
#Goffin "105676"
GOUP_W = sum(T_new_tot[T_new_tot['winner_id']==105676]['two_up'])
GOUP_D = sum(T_new_tot[T_new_tot['loser_id']==105676]['two_down'])
GODO_W = sum(T_new_tot[T_new_tot['winner_id']==105676]['two_down'])
GODO_D = T_new_tot[T_new_tot['loser_id']==105676]['two_up'].sum()
GOU_one_up = GOUP_W + GOUP_D
GOU_one_do = GODO_W + GODO_D
wi_go_up = (GOUP_W/GOU_one_up)*100
wi_go_do = (GODO_W/GOU_one_do)*100
goance_up = GOUP_W/GOU_one_up - GOUP_D/GOU_one_up
goance_do = GODO_W/GOU_one_do - GODO_D/GOU_one_do
#Carreno Busta 105807
CAUP_W = sum(T_new_tot[T_new_tot['winner_id']==105807]['two_up'])
CAUP_D = sum(T_new_tot[T_new_tot['loser_id']==105807]['two_down'])
CADO_W = sum(T_new_tot[T_new_tot['winner_id']==105807]['two_down'])
CADO_D = T_new_tot[T_new_tot['loser_id']==105807]['two_up'].sum()
CAU_one_up = CAUP_W + CAUP_D
CAU_one_do = CADO_W + CADO_D
wi_ca_up = (CAUP_W/CAU_one_up)*100
wi_ca_do = (CADO_W/CAU_one_do)*100
caance_up = CAUP_W/CAU_one_up - CAUP_D/CAU_one_up
caance_do = CADO_W/CAU_one_do - CADO_D/CAU_one_do
# "104527" #Wawrinka
WAUP_W = sum(T_new_tot[T_new_tot['winner_id']==104527]['two_up'])
WAUP_D = sum(T_new_tot[T_new_tot['loser_id']==104527]['two_down'])
WADO_W = sum(T_new_tot[T_new_tot['winner_id']==104527]['two_down'])
WADO_D = T_new_tot[T_new_tot['loser_id']==104527]['two_up'].sum()
WAU_one_up = WAUP_W + WAUP_D
WAU_one_do = WADO_W + WADO_D
wi_wa_up = (WAUP_W/WAU_one_up)*100
wi_wa_do = (WADO_W/WAU_one_do)*100
waance_up = WAUP_W/WAU_one_up - WAUP_D/WAU_one_up
waance_do = WADO_W/WAU_one_do - WADO_D/WAU_one_do
#Fognini 104926
FOUP_W = sum(T_new_tot[T_new_tot['winner_id']==104926]['two_up'])
FOUP_D = sum(T_new_tot[T_new_tot['loser_id']==104926]['two_down'])
FODO_W = sum(T_new_tot[T_new_tot['winner_id']==104926]['two_down'])
FODO_D = T_new_tot[T_new_tot['loser_id']==104926]['two_up'].sum()
FOU_one_up = FOUP_W + FOUP_D
FOU_one_do = FODO_W + FODO_D
wi_fo_up = (FOUP_W/FOU_one_up)*100
wi_fo_do = (FODO_W/FOU_one_do)*100
foance_up = FOUP_W/FOU_one_up - FOUP_D/FOU_one_up
foance_do = FODO_W/FOU_one_do - FODO_D/FOU_one_do
##Auger-Aliassime "200000"
#FAUP_W = sum(T_new_tot[T_new_tot['winner_id']==200000]['two_up'])
#FAUP_D = sum(T_new_tot[T_new_tot['loser_id']==200000]['two_down'])
#FADO_W = sum(T_new_tot[T_new_tot['winner_id']==200000]['two_down'])
#FADO_D = T_new_tot[T_new_tot['loser_id']==200000]['two_up'].sum()
#FAU_one_up = FAUP_W + FAUP_D
#FAU_one_do = FADO_W + FADO_D
#wi_faa_up = (FAUP_W/FAU_one_up)*100
#wi_faa_do = (FADO_W/FAU_one_do)*100
#faance_up = FAUP_W/FAU_one_up - FAUP_D/FAU_one_up
#faance_do = FADO_W/FAU_one_do - FADO_D/FAU_one_do
##Karen Khachanov "111575"
KKUP_W = sum(T_new_tot[T_new_tot['winner_id']==111575]['two_up'])
KKUP_D = sum(T_new_tot[T_new_tot['loser_id']==111575]['two_down'])
KKDO_W = sum(T_new_tot[T_new_tot['winner_id']==111575]['two_down'])
KKDO_D = T_new_tot[T_new_tot['loser_id']==111575]['two_up'].sum()
KKU_one_up = KKUP_W + KKUP_D
KKU_one_do = KKDO_W + KKDO_D
wi_kk_up = (KKUP_W/KKU_one_up)*100
wi_kk_do = (KKDO_W/KKU_one_do)*100
kkance_up = KKUP_W/KKU_one_up - KKUP_D/KKU_one_up
kkance_do = KKDO_W/KKU_one_do - KKDO_D/KKU_one_do
#Grigor Dimitrov "105777"
GDUP_W = sum(T_new_tot[T_new_tot['winner_id']==105777]['two_up'])
GDUP_D = sum(T_new_tot[T_new_tot['loser_id']==105777]['two_down'])
GDDO_W = sum(T_new_tot[T_new_tot['winner_id']==105777]['two_down'])
GDDO_D = T_new_tot[T_new_tot['loser_id']==105777]['two_up'].sum()
GDU_one_up = GDUP_W + GDUP_D
GDU_one_do = GDDO_W + GDDO_D
wi_gd_up = (GDUP_W/GDU_one_up)*100
wi_gd_do = (GDDO_W/GDU_one_do)*100
gdance_up = GDUP_W/GDU_one_up - GDUP_D/GDU_one_up
gdance_do = GDDO_W/GDU_one_do - GDDO_D/GDU_one_do

#ATTENTION: Auger-Aliassime RESULTS HAVE BEEN ASTERISKED DUE TO THE FACT THAT THE CANADIAN HAS TWO ZEROS ON THE BALANCE
#TWO DOWN WINS AND TWO DOWN DEFEATS. THE EXECUTION OF SCRIPT IS STILL POSSIBLE, BUT PYTHON IS RETURNING A NUMBER SCALAR 
#WARNING DUE TO THE FACT, THAT IS NOT POSSIBLE DIVIDE ZERO PER ZERO!!!!!! SO PAY ATTENTION.

#Define Dataset
data_2 = [['Nadal', TWOUP_W, TWOUP_D, TWODO_W, TWODO_D, wi_na_up, wi_na_do, Balance_two_up, Balance_two_do], 
          ['Djokovic', TWOUP_WNo, TWOUP_DNo, TWODO_WNo, TWODO_DNo, wi_di_up, wi_di_do, Bal_two_up, Bal_two_do],
          ['Federer', Wi_two_up, Lo_two_up, Wi_two_do, Lo_two_do, wi_fe_up, wi_fe_do, Bala_to_up, Bala_to_do],
          ['Thiem', THtwo_W, THtwo_D, THtwoDO_W, THtwoDO_D, wi_th_up, wi_th_do, twoth_up, twoth_do],
          ['Zverev', ZWUP_W, ZWEUP_D, ZWDO_W, ZWDO_D, wi_zw_up, wi_zw_do, zwance_up, zwance_do],
          ['Medvedev', MEUP_W, MEUP_D, MEDO_W, MEDO_D, wi_me_up, wi_me_do, meance_up, meance_do],
          ['Rublev', RUUP_W, RUUP_D, RUDO_W, RUDO_D, wi_ru_up, wi_ru_do, ruance_up, ruance_do],
          ['Tsitsipas', TSUP_W, TSUP_D, TSDO_W, TSDO_D, wi_ts_up, wi_ts_do, tsance_up, tsance_do],
          ['Schwartzman', SCUP_W, SCUP_D, SCDO_W, SCDO_D, wi_sc_up, wi_sc_do, scance_up, scance_do],
          ['Berrettini', BEUP_W, BEUP_D, BEDO_W, BEDO_D, wi_be_up, wi_be_do, beance_up, beance_do],
          ['Shapovalov', SHUP_W, SHUP_D, SHDO_W, SHDO_D, wi_sh_up, wi_sh_do, shance_up, shance_do],
          ['Monfils', MOUP_W, MOUP_D, MODO_W, MODO_D, wi_mo_up, wi_mo_do, moance_up, moance_do],
          ['Bautista-Agut', BAUP_W, BAUP_D, BADO_W, BADO_D, wi_ba_up, wi_ba_do, baance_up, baance_do],
          ['Raonic', RAUP_W, RAUP_D, RADO_W, RADO_D, wi_ra_up, wi_ra_do, raance_up, raance_do],
          ['Goffin', GOUP_W, GOUP_D, GODO_W, GODO_D, wi_go_up, wi_go_do, goance_up, goance_do],
          ['Carreno Busta', CAUP_W, CAUP_D, CADO_W, CADO_D, wi_ca_up, wi_ca_do, caance_up, caance_do],
          ['Wawrinka', WAUP_W, WAUP_D, WADO_W, WADO_D, wi_wa_up, wi_wa_do, waance_up, waance_do],
          ['Fognini', FOUP_W, FOUP_D, FODO_W, FODO_D, wi_fo_up, wi_fo_do, foance_up, foance_do],
          #['Auger-Aliassime', FAUP_W, FAUP_D, FADO_W, FADO_D, wi_faa_up, wi_faa_do, faance_up, faance_do], 
          ['Khachanov', KKUP_W, KKUP_D, KKDO_W, KKDO_D, wi_kk_up, wi_kk_do, kkance_up, kkance_do],
          ['Dimitrov', GDUP_W, GDUP_D, GDDO_W, GDDO_D, wi_gd_up, wi_gd_do, gdance_up, gdance_do]]

df_2 = pd.DataFrame(data_2, columns = ['Name', 'Nr_Win_twoup', 'Nr_Def_twoup', 'Nr_Win_twodo', 'Nr_Def_twodo', 
                                       'Per_Win_up', 'Per_Win_down', 'Balance_two_up', 'Balance_two_down'])

#df_2['Per_Win_down'] = df_2['Per_Win_down'].fillna(0)
#df_2['Balance_two_down'] = df_2['Balance_two_down'].fillna(0)
df_2['Total_cases'] = df_2['Nr_Win_twoup']+df_2['Nr_Def_twoup']+ df_2['Nr_Win_twodo']+ df_2['Nr_Def_twodo']

df_2 = df_2[['Name', 'Total_cases', 'Per_Win_up', 'Per_Win_down', 'Balance_two_up', 'Nr_Win_twoup', 
             'Nr_Def_twoup', 'Nr_Win_twodo', 'Nr_Def_twodo', 'Balance_two_down']].sort_values(by='Total_cases', ascending=False).round(3)

df2_styled = df_2.style.background_gradient()
df2_styled.to_excel("df2_styled.xlsx")
#df_2.dfi.export('df_2.png')

# %% [markdown]
# # DATA VISUALIZATION SECOND DATAFRAME

# %%
# Declaring the figure or the plot (y, x) or (width, height)
plt.figure(figsize=[15, 10])
# Data to be plotted
# Using numpy to group 3 different data with bars
X = np.arange(len(df_2))
# Passing the parameters to the bar function, this is the main function which creates the bar plot
# Using X now to align the bars side by side
plt.bar(X, df_2.Balance_two_up, color = 'g', width = 0.25)
plt.bar(X + 0.25, df_2.Balance_two_down, color = 'b', width = 0.25)
# Creating the legend of the bars in the plot
plt.legend(['Saldo_2_su', 'Saldo_2_giù'], loc='lower left', fontsize=15)
# Overiding the x axis with the country names
plt.xticks([i + 0.25 for i in range(21)], ['Fed', 'Djo', 'Waw', 'Nad', 'Fog', 'Mon', 'Thi', 'Rao', 'Gof', 'Bau', 
                                          'CaB', 'Kha', 'Sch', 'Dim', 'Zve', 'Med', 'Tsi', 'Ber', 'Rub', 'Sha',
                                          'Faa'], fontsize=13)
#plt.xticks([i + 0.25 for i in range(df_2.Name)])
#plt.xticks(df_2.Name)
# Giving the tilte for the plot
plt.title("Saldi due sets avanti e indietro Top 21", fontsize=25, fontweight="bold")
# Namimg the x and y axis
plt.xlabel('Tennisti', fontsize=15, fontweight="bold")
plt.ylabel('Valori', fontsize=15, fontweight="bold")
# Saving the plot as a 'png'
plt.savefig('Balance_two-up_two-down_3out5.png')
# Displaying the bar plot
plt.show()

# %% [markdown]
# # BUILDING TWO-ONE AND ONE-TWO DATAFRAME

# %%
#Big Three Balance two-one and one-two
TWONE_W = sum(T_new_tot[T_new_tot['winner_id']==104745]['two-one'])
TWONE_D = sum(T_new_tot[T_new_tot['loser_id']==104745]['one-two'])
ONTWO_W = sum(T_new_tot[T_new_tot['winner_id']==104745]['one-two'])
ONTWO_D = T_new_tot[T_new_tot['loser_id']==104745]['two-one'].sum()
COU_twone = TWONE_W + TWONE_D
COU_ontwo = ONTWO_W + ONTWO_D
wi_na_up = (TWONE_W/COU_twone)*100
wi_na_do = (ONTWO_W/COU_ontwo)*100
Balance_two_one = TWONE_W/COU_twone - TWONE_D/COU_twone
Balance_one_two = ONTWO_W/COU_ontwo - ONTWO_D/COU_ontwo
TWONE_WNo = sum(T_new_tot[T_new_tot['winner_id']==104925]['two-one'])
TWONE_DNo = sum(T_new_tot[T_new_tot['loser_id']==104925]['one-two'])
ONTWO_WNo = sum(T_new_tot[T_new_tot['winner_id']==104925]['one-two'])
ONTWO_DNo = T_new_tot[T_new_tot['loser_id']==104925]['two-one'].sum()
CO_twone = TWONE_WNo + TWONE_DNo
CO_ontwo = ONTWO_WNo + ONTWO_DNo
wi_di_up = (TWONE_WNo/CO_twone)*100
wi_di_do = (ONTWO_WNo/CO_ontwo)*100
Bal_two_one = TWONE_WNo/CO_twone - TWONE_DNo/CO_twone
Bal_one_two = ONTWO_WNo/CO_ontwo - ONTWO_DNo/CO_ontwo
Wi_twone = sum(T_new_tot[T_new_tot['winner_id']==103819]['two-one'])
Lo_twone = sum(T_new_tot[T_new_tot['loser_id']==103819]['one-two'])
Wi_ontwo = sum(T_new_tot[T_new_tot['winner_id']==103819]['one-two'])
Lo_ontwo = T_new_tot[T_new_tot['loser_id']==103819]['two-one'].sum()
Cou_twone = Wi_twone + Lo_twone
Cou_ontwo = Wi_ontwo + Lo_ontwo
wi_fe_up = (Wi_twone/Cou_twone)*100
wi_fe_do = (Wi_ontwo/Cou_ontwo)*100
Bala_twone = Wi_twone/Cou_twone - Lo_twone/Cou_twone
Bala_ontwo = Wi_ontwo/Cou_ontwo - Lo_ontwo/Cou_ontwo
#Thiem 106233
THtwo_W = sum(T_new_tot[T_new_tot['winner_id']==106233]['two-one'])
THtwo_D = sum(T_new_tot[T_new_tot['loser_id']==106233]['one-two'])
THtwoDO_W = sum(T_new_tot[T_new_tot['winner_id']==106233]['one-two'])
THtwoDO_D = T_new_tot[T_new_tot['loser_id']==106233]['two-one'].sum()
THU_two_up = THtwo_W + THtwo_D
THD_two_do = THtwoDO_W + THtwoDO_D
wi_th_up = (THtwo_W/THU_two_up)*100
wi_th_do = (THtwoDO_W/THD_two_do)*100
twoth_up = THtwo_W/THU_two_up - THtwo_D/THU_two_up
twoth_do = THtwoDO_W/THD_two_do - THtwoDO_D/THD_two_do
#Zverev "100644"
ZWUP_W = sum(T_new_tot[T_new_tot['winner_id']==100644]['two-one'])
ZWEUP_D = sum(T_new_tot[T_new_tot['loser_id']==100644]['one-two'])
ZWDO_W = sum(T_new_tot[T_new_tot['winner_id']==100644]['one-two'])
ZWDO_D = T_new_tot[T_new_tot['loser_id']==100644]['two-one'].sum()
ZWU_one_up = ZWUP_W + ZWEUP_D
ZWU_one_do = ZWDO_W + ZWDO_D
wi_zw_up = (ZWUP_W/ZWU_one_up)*100
wi_zw_do = (ZWDO_W/ZWU_one_do)*100
zwance_up = ZWUP_W/ZWU_one_up - ZWEUP_D/ZWU_one_up
zwance_do = ZWDO_W/ZWU_one_do - ZWDO_D/ZWU_one_do
#Medvedev "106421"
MEUP_W = sum(T_new_tot[T_new_tot['winner_id']==106421]['two-one'])
MEUP_D = sum(T_new_tot[T_new_tot['loser_id']==106421]['one-two'])
MEDO_W = sum(T_new_tot[T_new_tot['winner_id']==106421]['one-two'])
MEDO_D = T_new_tot[T_new_tot['loser_id']==106421]['two-one'].sum()
MEU_one_up = MEUP_W + MEUP_D
MEU_one_do = MEDO_W + MEDO_D
wi_me_up = (MEUP_W/MEU_one_up)*100
wi_me_do = (MEDO_W/MEU_one_do)*100
meance_up = MEUP_W/MEU_one_up - MEUP_D/MEU_one_up
meance_do = MEDO_W/MEU_one_do - MEDO_D/MEU_one_do
#Tsitsipas 126774
TSUP_W = sum(T_new_tot[T_new_tot['winner_id']==126774]['two-one'])
TSUP_D = sum(T_new_tot[T_new_tot['loser_id']==126774]['one-two'])
TSDO_W = sum(T_new_tot[T_new_tot['winner_id']==126774]['one-two'])
TSDO_D = T_new_tot[T_new_tot['loser_id']==126774]['two-one'].sum()
TSU_one_up = TSUP_W + TSUP_D
TSU_one_do = TSDO_W + TSDO_D
wi_ts_up = (TSUP_W/TSU_one_up)*100
wi_ts_do = (TSDO_W/TSU_one_do)*100
tsance_up = TSUP_W/TSU_one_up - TSUP_D/TSU_one_up
tsance_do = TSDO_W/TSU_one_do - TSDO_D/TSU_one_do
#Rublev 126094
RUUP_W = sum(T_new_tot[T_new_tot['winner_id']==126094]['two-one'])
RUUP_D = sum(T_new_tot[T_new_tot['loser_id']==126094]['one-two'])
RUDO_W = sum(T_new_tot[T_new_tot['winner_id']==126094]['one-two'])
RUDO_D = T_new_tot[T_new_tot['loser_id']==126094]['two-one'].sum()
RUU_one_up = RUUP_W + RUUP_D
RUU_one_do = RUDO_W + RUDO_D
wi_ru_up = (RUUP_W/RUU_one_up)*100
wi_ru_do = (RUDO_W/RUU_one_do)*100
ruance_up = RUUP_W/RUU_one_up - RUUP_D/RUU_one_up
ruance_do = RUDO_W/RUU_one_do - RUDO_D/RUU_one_do
#Schwartzman 106043
SCUP_W = sum(T_new_tot[T_new_tot['winner_id']==106043]['two-one'])
SCUP_D = sum(T_new_tot[T_new_tot['loser_id']==106043]['one-two'])
SCDO_W = sum(T_new_tot[T_new_tot['winner_id']==106043]['one-two'])
SCDO_D = T_new_tot[T_new_tot['loser_id']==106043]['two-one'].sum()
SCU_one_up = SCUP_W + SCUP_D
SCU_one_do = SCDO_W + SCDO_D
wi_sc_up = (SCUP_W/SCU_one_up)*100
wi_sc_do = (SCDO_W/SCU_one_do)*100
scance_up = SCUP_W/SCU_one_up - SCUP_D/SCU_one_up
scance_do = SCDO_W/SCU_one_do - SCDO_D/SCU_one_do
##Berettini 126610
BEUP_W = sum(T_new_tot[T_new_tot['winner_id']==126610]['two-one'])
BEUP_D = sum(T_new_tot[T_new_tot['loser_id']==126610]['one-two'])
BEDO_W = sum(T_new_tot[T_new_tot['winner_id']==126610]['one-two'])
BEDO_D = T_new_tot[T_new_tot['loser_id']==126610]['two-one'].sum()
BEU_one_up = BEUP_W + BEUP_D
BEU_one_do = BEDO_W + BEDO_D
wi_be_up = (BEUP_W/BEU_one_up)*100
wi_be_do = (BEDO_W/BEU_one_do)*100
beance_up = BEUP_W/BEU_one_up - BEUP_D/BEU_one_up
beance_do = BEDO_W/BEU_one_do - BEDO_D/BEU_one_do
#Shapovalov 133430
SHUP_W = sum(T_new_tot[T_new_tot['winner_id']==133430]['two-one'])
SHUP_D = sum(T_new_tot[T_new_tot['loser_id']==133430]['one-two'])
SHDO_W = sum(T_new_tot[T_new_tot['winner_id']==133430]['one-two'])
SHDO_D = T_new_tot[T_new_tot['loser_id']==133430]['two-one'].sum()
SHU_one_up = SHUP_W + SHUP_D
SHU_one_do = SHDO_W + SHDO_D
wi_sh_up = (SHUP_W/SHU_one_up)*100
wi_sh_do = (SHDO_W/SHU_one_do)*100
shance_up = SHUP_W/SHU_one_up - SHUP_D/SHU_one_up
shance_do = SHDO_W/SHU_one_do - SHDO_D/SHU_one_do
#Monfils 104792
MOUP_W = sum(T_new_tot[T_new_tot['winner_id']==104792]['two-one'])
MOUP_D = sum(T_new_tot[T_new_tot['loser_id']==104792]['one-two'])
MODO_W = sum(T_new_tot[T_new_tot['winner_id']==104792]['one-two'])
MODO_D = T_new_tot[T_new_tot['loser_id']==104792]['two-one'].sum()
MOU_one_up = MOUP_W + MOUP_D
MOU_one_do = MODO_W + MODO_D
wi_mo_up = (MOUP_W/MOU_one_up)*100
wi_mo_do = (MODO_W/MOU_one_do)*100
moance_up = MOUP_W/MOU_one_up - MOUP_D/MOU_one_up
moance_do = MODO_W/MOU_one_do - MODO_D/MOU_one_do
###Bautista Agut 105138
BAUP_W = sum(T_new_tot[T_new_tot['winner_id']==105138]['two-one'])
BAUP_D = sum(T_new_tot[T_new_tot['loser_id']==105138]['one-two'])
BADO_W = sum(T_new_tot[T_new_tot['winner_id']==105138]['one-two'])
BADO_D = T_new_tot[T_new_tot['loser_id']==105138]['two-one'].sum()
BAU_one_up = BAUP_W + BAUP_D
BAU_one_do = BADO_W + BADO_D
wi_ba_up = (BAUP_W/BAU_one_up)*100
wi_ba_do = (BADO_W/BAU_one_do)*100
baance_up = BAUP_W/BAU_one_up - BAUP_D/BAU_one_up
baance_do = BADO_W/BAU_one_do - BADO_D/BAU_one_do
#Raonic  "105683"
RAUP_W = sum(T_new_tot[T_new_tot['winner_id']==105683]['two-one'])
RAUP_D = sum(T_new_tot[T_new_tot['loser_id']==105683]['one-two'])
RADO_W = sum(T_new_tot[T_new_tot['winner_id']==105683]['one-two'])
RADO_D = T_new_tot[T_new_tot['loser_id']==105683]['two-one'].sum()
RAU_one_up = RAUP_W + RAUP_D
RAU_one_do = RADO_W + RADO_D
wi_ra_up = (RAUP_W/RAU_one_up)*100
wi_ra_do = (RADO_W/RAU_one_do)*100
raance_up = RAUP_W/RAU_one_up - RAUP_D/RAU_one_up
raance_do = RADO_W/RAU_one_do - RADO_D/RAU_one_do
#Goffin "105676"
GOUP_W = sum(T_new_tot[T_new_tot['winner_id']==105676]['two-one'])
GOUP_D = sum(T_new_tot[T_new_tot['loser_id']==105676]['one-two'])
GODO_W = sum(T_new_tot[T_new_tot['winner_id']==105676]['one-two'])
GODO_D = T_new_tot[T_new_tot['loser_id']==105676]['two-one'].sum()
GOU_one_up = GOUP_W + GOUP_D
GOU_one_do = GODO_W + GODO_D
wi_go_up = (GOUP_W/GOU_one_up)*100
wi_go_do = (GODO_W/GOU_one_do)*100
goance_up = GOUP_W/GOU_one_up - GOUP_D/GOU_one_up
goance_do = GODO_W/GOU_one_do - GODO_D/GOU_one_do
#Carreno Busta 105807
CAUP_W = sum(T_new_tot[T_new_tot['winner_id']==105807]['two-one'])
CAUP_D = sum(T_new_tot[T_new_tot['loser_id']==105807]['one-two'])
CADO_W = sum(T_new_tot[T_new_tot['winner_id']==105807]['one-two'])
CADO_D = T_new_tot[T_new_tot['loser_id']==105807]['two-one'].sum()
CAU_one_up = CAUP_W + CAUP_D
CAU_one_do = CADO_W + CADO_D
wi_ca_up = (CAUP_W/CAU_one_up)*100
wi_ca_do = (CADO_W/CAU_one_do)*100
caance_up = CAUP_W/CAU_one_up - CAUP_D/CAU_one_up
caance_do = CADO_W/CAU_one_do - CADO_D/CAU_one_do
# "104527" #Wawrinka
WAUP_W = sum(T_new_tot[T_new_tot['winner_id']==104527]['two-one'])
WAUP_D = sum(T_new_tot[T_new_tot['loser_id']==104527]['one-two'])
WADO_W = sum(T_new_tot[T_new_tot['winner_id']==104527]['one-two'])
WADO_D = T_new_tot[T_new_tot['loser_id']==104527]['two-one'].sum()
WAU_one_up = WAUP_W + WAUP_D
WAU_one_do = WADO_W + WADO_D
wi_wa_up = (WAUP_W/WAU_one_up)*100
wi_wa_do = (WADO_W/WAU_one_do)*100
waance_up = WAUP_W/WAU_one_up - WAUP_D/WAU_one_up
waance_do = WADO_W/WAU_one_do - WADO_D/WAU_one_do
#Fognini 104926
FOUP_W = sum(T_new_tot[T_new_tot['winner_id']==104926]['two-one'])
FOUP_D = sum(T_new_tot[T_new_tot['loser_id']==104926]['one-two'])
FODO_W = sum(T_new_tot[T_new_tot['winner_id']==104926]['one-two'])
FODO_D = T_new_tot[T_new_tot['loser_id']==104926]['two-one'].sum()
FOU_one_up = FOUP_W + FOUP_D
FOU_one_do = FODO_W + FODO_D
wi_fo_up = (FOUP_W/FOU_one_up)*100
wi_fo_do = (FODO_W/FOU_one_do)*100
foance_up = FOUP_W/FOU_one_up - FOUP_D/FOU_one_up
foance_do = FODO_W/FOU_one_do - FODO_D/FOU_one_do
#Auger-Aliassime "200000"
FAUP_W = sum(T_new_tot[T_new_tot['winner_id']==200000]['two-one'])
FAUP_D = sum(T_new_tot[T_new_tot['loser_id']==200000]['one-two'])
FADO_W = sum(T_new_tot[T_new_tot['winner_id']==200000]['one-two'])
FADO_D = T_new_tot[T_new_tot['loser_id']==200000]['two-one'].sum()
FAU_one_up = FAUP_W + FAUP_D
FAU_one_do = FADO_W + FADO_D
wi_faa_up = (FAUP_W/FAU_one_up)*100
wi_faa_do = (FADO_W/FAU_one_do)*100
faance_up = FAUP_W/FAU_one_up - FAUP_D/FAU_one_up
faance_do = FADO_W/FAU_one_do - FADO_D/FAU_one_do
#Karen Khachanov "111575"
KKUP_W = sum(T_new_tot[T_new_tot['winner_id']==111575]['two-one'])
KKUP_D = sum(T_new_tot[T_new_tot['loser_id']==111575]['one-two'])
KKDO_W = sum(T_new_tot[T_new_tot['winner_id']==111575]['one-two'])
KKDO_D = T_new_tot[T_new_tot['loser_id']==111575]['two-one'].sum()
KKU_one_up = KKUP_W + KKUP_D
KKU_one_do = KKDO_W + KKDO_D
wi_kk_up = (KKUP_W/KKU_one_up)*100
wi_kk_do = (KKDO_W/KKU_one_do)*100
kkance_up = KKUP_W/KKU_one_up - KKUP_D/KKU_one_up
kkance_do = KKDO_W/KKU_one_do - KKDO_D/KKU_one_do
#Grigor Dimitrov "105777"
GDUP_W = sum(T_new_tot[T_new_tot['winner_id']==105777]['two-one'])
GDUP_D = sum(T_new_tot[T_new_tot['loser_id']==105777]['one-two'])
GDDO_W = sum(T_new_tot[T_new_tot['winner_id']==105777]['one-two'])
GDDO_D = T_new_tot[T_new_tot['loser_id']==105777]['two-one'].sum()
GDU_one_up = GDUP_W + GDUP_D
GDU_one_do = GDDO_W + GDDO_D
wi_gd_up = (GDUP_W/GDU_one_up)*100
wi_gd_do = (GDDO_W/GDU_one_do)*100
gdance_up = GDUP_W/GDU_one_up - GDUP_D/GDU_one_up
gdance_do = GDDO_W/GDU_one_do - GDDO_D/GDU_one_do

data_3 = [['Nadal', TWONE_W, TWONE_D, ONTWO_W, ONTWO_D, wi_na_up, wi_na_do, Balance_two_one, Balance_one_two],
          ['Djokovic', TWONE_WNo, TWONE_DNo, ONTWO_WNo, ONTWO_DNo, wi_di_up, wi_di_do, Bal_two_one, Bal_one_two],
          ['Federer', Wi_twone , Lo_twone, Wi_ontwo, Lo_ontwo, wi_fe_up, wi_fe_do, Bala_twone, Bala_ontwo],
          ['Thiem', THtwo_W, THtwo_D, THtwoDO_W, THtwoDO_D, wi_th_up, wi_th_do, twoth_up, twoth_do],
          ['Zverev', ZWUP_W, ZWEUP_D, ZWDO_W, ZWDO_D, wi_zw_up, wi_zw_do, zwance_up, zwance_do],
          ['Medvedev', MEUP_W, MEUP_D, MEDO_W, MEDO_D, wi_me_up, wi_me_do, meance_up, meance_do],
          ['Rublev', RUUP_W, RUUP_D, RUDO_W, RUDO_D, wi_ru_up, wi_ru_do, ruance_up, ruance_do],
          ['Tsitsipas', TSUP_W, TSUP_D, TSDO_W, TSDO_D, wi_ts_up, wi_ts_do, tsance_up, tsance_do],
          ['Schwartzman', SCUP_W, SCUP_D, SCDO_W, SCDO_D, wi_sc_up, wi_sc_do, scance_up, scance_do],
          ['Berrettini', BEUP_W, BEUP_D, BEDO_W, BEDO_D, wi_na_up, wi_na_do, beance_up, beance_do],
          ['Shapovalov', SHUP_W, SHUP_D, SHDO_W, SHDO_D, wi_sh_up, wi_sh_do, shance_up, shance_do],
          ['Monfils', MOUP_W, MOUP_D, MODO_W, MODO_D, wi_mo_up, wi_mo_do, moance_up, moance_do],
          ['Bautista-Agut', BAUP_W, BAUP_D, BADO_W, BADO_D, wi_ba_up, wi_ba_do, baance_up, baance_do],
          ['Raonic', RAUP_W, RAUP_D, RADO_W, RADO_D, wi_ra_up, wi_ra_do, raance_up, raance_do],
          ['Goffin', GOUP_W, GOUP_D, GODO_W, GODO_D, wi_go_up, wi_go_do, goance_up, goance_do],
          ['Carreno Busta', CAUP_W, CAUP_D, CADO_W, CADO_D, wi_ca_up, wi_ca_do, caance_up, caance_do],
          ['Wawrinka', WAUP_W, WAUP_D, WADO_W, WADO_D, wi_wa_up, wi_wa_do, waance_up, waance_do],
          ['Fognini', FOUP_W, FOUP_D, FODO_W, FODO_D, wi_fo_up, wi_fo_do, foance_up, foance_do],
          ['Auger-Aliassime', FAUP_W, FAUP_D, FADO_W, FADO_D, wi_faa_up, wi_faa_do, faance_up, faance_do],
          ['Khachanov', KKUP_W, KKUP_D, KKDO_W, KKDO_D, wi_kk_up, wi_kk_do, kkance_up, kkance_do],
          ['Dimitrov', GDUP_W, GDUP_D, GDDO_W, GDDO_D, wi_gd_up, wi_gd_do, gdance_up, gdance_do]]

df_3 = pd.DataFrame(data_3, columns = ['Name','Nr_Win_two-one', 'Nr_Def_two-one', 'Nr_Win_one-two', 'Nr_Def_one-two',
                                       'Per_Win_Two-one', 'Per_Win_One_two', 'Balance_two_one', 'Balance_one_two'])
df_3['Total_cases'] = df_3['Nr_Win_two-one']+df_3['Nr_Def_two-one']+ df_3['Nr_Win_one-two']+ df_3['Nr_Def_one-two']

#'Nr_Win_two-one', 'Nr_Def_two-one', 'Nr_Win_one-two','Nr_Def_one-two'
df_3 = df_3[['Name', 'Total_cases', 'Per_Win_Two-one', 'Per_Win_One_two', 
             'Balance_two_one', 'Balance_one_two']].sort_values(by='Total_cases', ascending=False).round(3)


df3_styled = df_3.style.background_gradient()
df3_styled.to_excel("df3_styled.xlsx")
#df_3.dfi.export('df_3.png')

# %% [markdown]
# # DATA VISUALIZATION THIRD DATAFRAME

# %%
# Declaring the figure or the plot (y, x) or (width, height)
plt.figure(figsize=[15, 10])
# Data to be plotted
# Using numpy to group 3 different data with bars
X = np.arange(len(df_3))
# Passing the parameters to the bar function, this is the main function which creates the bar plot
# Using X now to align the bars side by side
plt.bar(X, df_3.Balance_two_one, color = 'g', width = 0.25)
plt.bar(X + 0.25, df_3.Balance_one_two, color = 'b', width = 0.25)
# Creating the legend of the bars in the plot
plt.legend(['Saldo_2-1', 'Saldo_1-2'], loc='lower left', fontsize=15)
# Overiding the x axis with the country names
plt.xticks([i + 0.25 for i in range(21)], ['Fed', 'Djo', 'Waw', 'Nad', 'Mon', 'Fog', 'Rao', 'Thi', 'Gof', 'Bau', 
                                          'Dim', 'Zve', 'CaB', 'Kha', 'Sch', 'Med', 'Sha', 'Tsi', 'Rub','Ber',
                                          'Faa'], fontsize=13)
#plt.xticks([i + 0.25 for i in range(df_2.Name)])
#plt.xticks(df_2.Name)
# Giving the tilte for the plot
plt.title("Saldi due-uno e uno-due Top 21", fontsize=25, fontweight="bold")
# Namimg the x and y axis
plt.xlabel('Tennisti', fontsize=15, fontweight="bold")
plt.ylabel('Valori', fontsize=15, fontweight="bold")
# Saving the plot as a 'png'
plt.savefig('Balance_two-one_one-two.png')
# Displaying the bar plot
plt.show()
